# %% [markdown]
# # Árvores de regressão - exercícios 01
#
# Nesta bateria de exercícios, vamos botar em prática o que aprendemos com a base de dados imobiliários de Boston, que pode ser baixada do módulo ```datasets``` do scikitlearn. Essa base de dados possui uma linha por cidade, o objetivo é prever, ou fornecer uma estimativa de ```MEDV```, ou o valor mediano de casas ocupadas pelo dono, dadas as demais variáveis usadas como explicativas.
#
# A descrição das variáveis está abaixo:

# %% [markdown]
# | Variavel | Descrição|
# |-|-|
# |CRIM| taxa de crimes per-cápita da cidade |
# |ZN| proporção de terrenos residenciais zoneados para lotes com mais de 25.000 pés quadrados. |
# |INDUS| proporção de acres de negócios não varejistas por cidade |
# |CHAS |vale 1 se o terreno faz fronteira com o *Charles River*; 0 caso contrário |
# |NOX| Concentração de óxido nítrico (em partes por 10 milhões) |
# |RM| número médio de quartos por habitação |
# |AGE| proporção de unidades ocupadas pelo proprietário construídas antes de 1940 |
# |DIS| distâncias ponderadas até cinco centros de empregos de Boston |
# |RAD| índice de acessibilidade a rodovias radiais |
# |TAX| taxa de imposto sobre a propriedade de valor total por \\$10,000 |
# |PTRATIO| razão pupilo-professor da cidade |
# |B| $ 1000 (Bk - 0,63) ^ 2 $ onde Bk é a proporção de negros por cidade |
# |LSTAT| \%status inferior da população |
# |MEDV| (variável resposta) Valor mediano das casas ocupadas pelo proprietário em US $ 1.000|

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split


boston = datasets.load_boston()
X = pd.DataFrame(boston.data, columns = boston.feature_names)
y = pd.DataFrame(boston.target, columns = ['MEDV'])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning:
#
# Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y.head()
# Out:
#    MEDV
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %% [markdown]
# ### 1. Certifique-se de que esta base está no formato adequado para o scikitlearn.
# ok, essa tarefa é tão fácil que você vai até desconfiar. Mas é preciso ter confiança sobre os dados que se usa ;)

# %%
X.info()
#Ok, we don't have any categorical value and no empty value either
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %% [markdown]
# ### 2.  Visualize a matriz de correlação, e veja se aparentemente você encontra alguma variável com potencial preditivo interessante.

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data=X.corr(),cmap='coolwarm',center=0,vmin=-1,vmax=1,annot=True);plt.show()

# %%
#INDUS,TAX,NOX talvez DIS pra correlação negativa

# %% [markdown]
# ### 3. Separe os dados em validação e teste

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=2360873)

# %% [markdown]
# ### 4. Treine duas árvores, uma com profundidade máxima = 8, outra com profundidade máxima = 2.

# %%
regressor1 = DecisionTreeRegressor(max_depth=8)
regressor2 = DecisionTreeRegressor(max_depth=2)

regressor1 = regressor1.fit(X_train,y_train)
regressor2= regressor2.fit(X_train,y_train)

# %% [markdown]
# ### 5. Calcule o MSE de cada uma das árvores do item anterior para a base de treinamento e para a base de testes.

# %%
#  Erro Quadrático Médio (Mean Squared Error - MSE)
from sklearn.metrics import mean_squared_error,r2_score

predict1 = regressor1.predict(X_train)
predict2 = regressor2.predict(X_train)

mse1 = mean_squared_error(y_train,predict1)
mse2 = mean_squared_error(y_train,predict2)

print(f'MSE 1 e 2 para a base de treino \n{mse1}\n{mse2}')
# Out:
# MSE 1 e 2 para a base de treino
# 1.800555359843342
# 25.84925110765039

# %%
predict1 = regressor1.predict(X_test)
predict2 = regressor2.predict(X_test)

mse1 = mean_squared_error(y_test,predict1)
mse2 = mean_squared_error(y_test,predict2)


print(f'MSE 1 e 2 para a base de teste \n{mse1}\n{mse2}')
# Out:
# MSE 1 e 2 para a base de teste
# 12.427842586163962
# 26.462349543492344

# %% [markdown]
# ### 6. Com base nos resultados do item anterior, qual árvore te parece mais adequada?

# %% [markdown]
# A com profundidade 2 me parece bem mais agradável, umas vez que vejo que a primeira arvore têm um MSE muito baixo para os dados de treino, o que é extremamente bom, ela acaba pegando até os ruídos dos dados. Porém quando observamos o MSE da arvore 1(profundidade 8) nos dados de teste, ele varia muito, sobe pra 26. Então me agrada mais a arvore 2 que se mantêm consistente em 25 e 26 os MSE's de treino e teste.

# %% [markdown]
# ### 7. Faça uma visualização gráfica dessa árvore. Vamos discutir importância de variável mais adiante, mas veja a sua árvore, e pense um pouco: qual variável te parece mais "importante" na árvore?

# %%
plt.figure(figsize=(10,10))
tree.plot_tree(regressor2,feature_names=X.columns,filled=True);plt.show()

# %%
df = y_test
df['Predict2'] = predict2
df.rename(columns={'MEDV':'y_test'},inplace=True)

# %%
df1 = df.sort_index()
df1
# Out:
#      y_test   Predict2
# 2      34.7  32.860000
# 3      33.4  32.860000
# 4      36.2  32.860000
# 11     18.9  23.682105
# 12     21.7  14.725714
# ..      ...        ...
# 492    20.1  23.682105
# 493    21.8  23.682105
# 497    18.3  23.682105
# 504    22.0  23.682105
# 505    11.9  23.682105
#
# [127 rows x 2 columns]

# %%
sns.lineplot(data=df1,x=df1.index,y='y_test',label='Valores Reais',color='g')
sns.lineplot(data=df1,x=df1.index,y='Predict2',label='Valores Preditos',color='b',)
# Out:
# <AxesSubplot:ylabel='y_test'>
